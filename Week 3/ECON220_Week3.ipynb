# %% [markdown]
# ## ECON 220 Lab Week 3

# %% [markdown]
# Justin S. Eloriaga

# %% [markdown]
# For this week, we will be building a dataset together in class. In this file, I will use a randomly generated dataset but we will replace this with our actual dataset. This will be a dataset we will repeatedly go back to and that we will build together

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Next, I specify again the path and load the csv file

# %%
# Writing the path
path = "/Users/justineloriaga/Documents/GitHub/ECON-220-Lab/Week 3/random_dataset.csv"

# Loading the data
data = pd.read_csv(path)
data
# Out:
#    Lastname Firstname  Blue  Orange  Green  Yellow  Red  Brown  Other  Total
# 0     MKFHJ     NOWCP     5       2      5       0    3      0      3     18
# 1     TFFEJ     ELPOT     4       3      3       2    1      5      0     18
# 2     TCPZF     IOLRT     4       0      3       4    1      2      2     16
# 3     TBIBN     WFRCH     2       4      2       4    0      2      4     18
# 4     RJXIG     WLTCX     0       2      1       4    3      5      4     19
# ..      ...       ...   ...     ...    ...     ...  ...    ...    ...    ...
# 95    JEBTM     DSQKW     2       3      0       5    4      4      1     19
# 96    VWXNM     VAXKJ     1       0      4       3    3      0      5     16
# 97    THFHV     XJSDM     2       3      3       1    0      4      4     17
# 98    YAHAO     OWITZ     5       3      0       3    1      3      3     18
# 99    DVZLI     DCTRX     1       2      2       4    5      4      1     19
#
# [100 rows x 10 columns]

# %% [markdown]
# Suppose we want to know the proportion of Blue M&M's per pack. We can get that using the form $$blue\_prop = \frac{\text{\# of Blue M\&M Per Pack}}{\text{Total M\&M Per Pack}} $$

# %% [markdown]
# We can generate a variable using the simple variable creation method below

# %%
data['Blue_prop'] = data['Blue'] / data['Total']
data
# Out:
#    Lastname Firstname  Blue  Orange  Green  Yellow  Red  Brown  Other  Total  \
# 0     MKFHJ     NOWCP     5       2      5       0    3      0      3     18
# 1     TFFEJ     ELPOT     4       3      3       2    1      5      0     18
# 2     TCPZF     IOLRT     4       0      3       4    1      2      2     16
# 3     TBIBN     WFRCH     2       4      2       4    0      2      4     18
# 4     RJXIG     WLTCX     0       2      1       4    3      5      4     19
# ..      ...       ...   ...     ...    ...     ...  ...    ...    ...    ...
# 95    JEBTM     DSQKW     2       3      0       5    4      4      1     19
# 96    VWXNM     VAXKJ     1       0      4       3    3      0      5     16
# 97    THFHV     XJSDM     2       3      3       1    0      4      4     17
# 98    YAHAO     OWITZ     5       3      0       3    1      3      3     18
# 99    DVZLI     DCTRX     1       2      2       4    5      4      1     19
#
#     Blue_prop
# 0    0.277778
# ...

# %% [markdown]
# From here, we can generate a for loop to create variables for the other colors. In essence, instead of repeating the command 6 more times, we can generate a loop that will do it in one go.

# %%
colors = ['Orange', 'Green', 'Yellow', 'Red', 'Brown', 'Other']
for color in colors:
    data[color + '_prop'] = data[color] / data['Total']
# Out:
#    Lastname Firstname  Blue  Orange  Green  Yellow  Red  Brown  Other  Total  \
# 0     MKFHJ     NOWCP     5       2      5       0    3      0      3     18
# 1     TFFEJ     ELPOT     4       3      3       2    1      5      0     18
# 2     TCPZF     IOLRT     4       0      3       4    1      2      2     16
# 3     TBIBN     WFRCH     2       4      2       4    0      2      4     18
# 4     RJXIG     WLTCX     0       2      1       4    3      5      4     19
# ..      ...       ...   ...     ...    ...     ...  ...    ...    ...    ...
# 95    JEBTM     DSQKW     2       3      0       5    4      4      1     19
# 96    VWXNM     VAXKJ     1       0      4       3    3      0      5     16
# 97    THFHV     XJSDM     2       3      3       1    0      4      4     17
# 98    YAHAO     OWITZ     5       3      0       3    1      3      3     18
# 99    DVZLI     DCTRX     1       2      2       4    5      4      1     19
#
# ...

# %% [markdown]
# Next, let us plot a histogram. A histogram is a useful representation particularly for understanding distributions. Here, let us understand the distribution of the proportion of blue M&M's

# %%
plt.figure()
data['Blue_prop'].hist(bins=20, color='blue')
plt.title('Histogram of Blue Proportion')
plt.xlabel('Proportion')
plt.ylabel('Frequency')
plt.show()

# %%
mean_proportions = data[['Blue_prop', 'Orange_prop', 'Green_prop', 'Yellow_prop', 'Red_prop', 'Brown_prop', 'Other_prop']].mean()
mean_proportions
# Out:
# Blue_prop      0.149946
# Orange_prop    0.154594
# Green_prop     0.150901
# Yellow_prop    0.136330
# Red_prop       0.122674
# Brown_prop     0.143452
# Other_prop     0.142102
# dtype: float64

# %%
variance_proportions = data[['Blue_prop', 'Orange_prop', 'Green_prop', 'Yellow_prop', 'Red_prop', 'Brown_prop', 'Other_prop']].var()
variance_proportions
# Out:
# Blue_prop      0.008736
# Orange_prop    0.009640
# Green_prop     0.010006
# Yellow_prop    0.009629
# Red_prop       0.009744
# Brown_prop     0.009180
# Other_prop     0.010818
# dtype: float64

# %% [markdown]
# Next, let us discuss some simple data management logistics, like sorting a dataset

# %%
# Sort the data by the Total column
data.sort_values(by='Total', ascending=False)
# Out:
#    Lastname Firstname  Blue  Orange  Green  Yellow  Red  Brown  Other  Total  \
# 99    DVZLI     DCTRX     1       2      2       4    5      4      1     19
# 13    JTROM     UKCYE     3       4      2       5    2      2      1     19
# 44    MQHWY     QZIWU     1       5      0       5    1      2      5     19
# 46    CUIWO     LRFTA     5       1      2       2    4      2      3     19
# 48    QGSQW     RWZEY     1       3      2       3    4      4      2     19
# ..      ...       ...   ...     ...    ...     ...  ...    ...    ...    ...
# 84    NSRWQ     GLMNS     3       1      1       2    0      4      4     15
# 63    ILFPU     ZJCOX     3       0      0       2    5      4      1     15
# 81    YLEEV     ZEXZY     3       2      4       4    0      2      0     15
# 64    CDATA     ERYJF     3       3      3       3    2      0      1     15
# 58    PSKAN     LHCMK     1       2      3       5    1      0      3     15
#
# ...

# %% [markdown]
# Lastly, to convert your Jupyter notebook to a .html, merely follow this code:

# %% [markdown]
# !jupyter nbconvert --to html FILENAME.ipynb

# %% [markdown]
# So in my case, I will use the following

# %%
# !jupyter nbconvert --to html ECON220_Week3.ipynb
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: kernel kernelspec migrate run troubleshoot
#
# Jupyter command `jupyter-nbconvert` not found.
